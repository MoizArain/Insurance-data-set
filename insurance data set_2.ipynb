# %%
import pandas as pd
import matplotlib.pyplot as plt  
import numpy as np

# %%
path = r'C:\Users\moiez\OneDrive\Desktop\insurance.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.max()
# Out:
# age                  64
# gender             male
# bmi               53.13
# children              5
# smoker              yes
# region        southwest
# charges     63770.42801
# dtype: object

# %%
w = df["age"]
x = df["charges"]
y = df["bmi"]
z = df["children"]
plt.plot(w)

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(z)

# %%
plt.scatter(w,x)

# %%
plt.scatter(x,y)

# %%
plt.scatter(y,z)

# %%
plt.scatter(z,w)

# %%
plt.scatter(w,y)

# %%
df.loc[df["region"] == "southeast"]
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# 11     62  female  26.29         0    yes  southeast  27808.7251
# ...   ...     ...    ...       ...    ...        ...         ...
# 1322   62    male  38.83         0     no  southeast  12981.3457
# 1323   42  female  40.37         2    yes  southeast  43896.3763
# 1327   51    male  30.03         1     no  southeast   9377.9047
# 1330   57  female  25.74         2     no  southeast  12629.1656
# 1335   18  female  36.85         0     no  southeast   1629.8335
#
# [364 rows x 7 columns]

# %%
q = df.loc[df["region"] == "southeast"]
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# 11     62  female  26.29         0    yes  southeast  27808.7251
# ...   ...     ...    ...       ...    ...        ...         ...
# 1322   62    male  38.83         0     no  southeast  12981.3457
# 1323   42  female  40.37         2    yes  southeast  43896.3763
# 1327   51    male  30.03         1     no  southeast   9377.9047
# 1330   57  female  25.74         2     no  southeast  12629.1656
# 1335   18  female  36.85         0     no  southeast   1629.8335
#
# [364 rows x 7 columns]

# %%
w = df.loc[df["region"] == "southwest"]
w
# Out:
#       age  gender   bmi  children smoker     region      charges
# 0      19  female  27.9         0    yes  southwest  16884.92400
# 12     23    male  34.4         0     no  southwest   1826.84300
# 15     19    male  24.6         1     no  southwest   1837.23700
# 18     56    male  40.3         0     no  southwest  10602.38500
# 19     30    male  35.3         0    yes  southwest  36837.46700
# ...   ...     ...   ...       ...    ...        ...          ...
# 1316   19  female  20.6         0     no  southwest   1731.67700
# 1329   52    male  38.6         2     no  southwest  10325.20600
# 1331   23  female  33.4         0     no  southwest  10795.93733
# 1332   52  female  44.7         3     no  southwest  11411.68500
# 1336   21  female  25.8         0     no  southwest   2007.94500
#
# [325 rows x 7 columns]

# %%
plt.plot(q["age"],q["charges"])
plt.show()

# %%
plt.plot(w["age"],w["charges"])
plt.show()

# %%
plt.scatter(q["age"],q["charges"])
plt.show()

# %%
plt.scatter(w["age"],w["charges"])
plt.show()

# %%
(df.charges.sum())/1000000
# Out:
# 17.755824990759
